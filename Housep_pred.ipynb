# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#boston house price dataset
df=pd.read_csv("BostonHousing.csv")
df.head(2)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
#
#        b  lstat  medv
# 0  396.9   4.98  24.0
# 1  396.9   9.14  21.6

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.corr(), annot=True, fmt=".1f");

# %%
plt.scatter(df['crim'],df['medv'])
plt.xlabel("Crime-Rate")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
#regression plot on avg room and price
sns.regplot(x="rm",y='medv',data=df)
# Out:
# <Axes: xlabel='rm', ylabel='medv'>

# %%
#regression plot on crime and price
sns.regplot(x="crim",y="medv",data=df)
# Out:
# <Axes: xlabel='crim', ylabel='medv'>

# %%
#regression plot on chas and price
sns.regplot(x="chas",y="medv",data=df)
# Out:
# <Axes: xlabel='chas', ylabel='medv'>

# %%
#regression plot on ptratio and price
sns.regplot(x='ptratio',y="medv",data=df)#inversely corelated
# Out:
# <Axes: xlabel='ptratio', ylabel='medv'>

# %% [markdown]
# Independent and Dependent features

# %%
x=df.iloc[:,:-1]
x
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %% [markdown]
# Train Test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=21)
x_train
# Out:
#         crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 288  0.04590  52.5   5.32     0  0.405  6.315   45.6  7.3172    6  293
# 464  7.83932   0.0  18.10     0  0.655  6.209   65.4  2.9634   24  666
# 443  9.96654   0.0  18.10     0  0.740  6.485  100.0  1.9784   24  666
# 395  8.71675   0.0  18.10     0  0.693  6.471   98.8  1.7257   24  666
# 14   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# ..       ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 48   0.25387   0.0   6.91     0  0.448  5.399   95.3  5.8700    3  233
# 260  0.54011  20.0   3.97     0  0.647  7.203   81.8  2.1121    5  264
# 312  0.26169   0.0   9.90     0  0.544  6.023   90.4  2.8340    4  304
# 207  0.25199   0.0  10.59     0  0.489  5.783   72.7  4.3549    4  277
# 457  8.20058   0.0  18.10     0  0.713  5.936   80.3  2.7792   24  666
#
#      ptratio       b  lstat
# 288     16.6  396.90   7.60
# 464     20.2  396.90  13.22
# ...

# %%
y_train
# Out:
# 288    22.3
# 464    21.4
# 443    15.4
# 395    13.1
# 14     18.2
#        ...
# 48     14.4
# 260    33.8
# 312    19.4
# 207    22.5
# 457    13.5
# Name: medv, Length: 354, dtype: float64

# %%
#standard Scalar
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
x_train
# Out:
# array([[-0.46900271,  1.92499122, -0.87051996, ..., -0.87455862,
#          0.44753165, -0.71835228],
#        [ 0.638131  , -0.46941107,  1.00871752, ...,  0.80472043,
#          0.44753165,  0.0740162 ],
#        [ 0.94032399, -0.46941107,  1.00871752, ...,  0.80472043,
#          0.32746914,  0.8677946 ],
#        ...,
#        [-0.43834757, -0.46941107, -0.19705301, ..., -0.0349191 ,
#          0.44044831, -0.13747005],
#        [-0.43972555, -0.46941107, -0.09559183, ...,  0.05837419,
#          0.35934414,  0.75641184],
#        [ 0.68945161, -0.46941107,  1.00871752, ...,  0.80472043,
#         -4.19677437,  0.5985021 ]])

# %%
x_test
# Out:
# array([[ 0.04553688, -0.53199656,  1.03363885, ...,  0.81124793,
#         -2.87175317,  0.77121528],
#        [-0.08006646, -0.53199656,  1.24599651, ..., -1.68214645,
#          0.43620858,  1.9734137 ],
#        [-0.30213898, -0.53199656, -0.1429374 , ..., -0.00477205,
#          0.43620858, -0.90964903],
#        ...,
#        [-0.36673959, -0.53199656, -0.98232411, ..., -0.82079203,
#          0.4237791 , -0.86676278],
#        [-0.34597273, -0.53199656,  1.57744665, ...,  1.26459237,
#          0.35187936,  1.60542201],
#        [-0.18238704, -0.53199656,  1.24599651, ..., -1.68214645,
#         -1.74019275,  0.56646802]])

# %% [markdown]
# Training model

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#print the coeff and intercept
print(le.coef_)
# Out:
# [-0.74904652  1.19738131  0.08405358  0.54927308 -2.07987862  2.29069311
#   0.10512626 -2.92354695  3.08117052 -2.3139199  -2.26799857  0.99758097
#  -3.71735067]

# %%
print(le.intercept_)
# Out:
# 22.541807909604522

# %% [markdown]
# Predeiction

# %%
y_pred= le.predict(x_test)
y_pred
# Out:
# array([15.81344795, 14.53676457, 26.43633836, 37.3222918 , 32.98788265,
#        12.55108124, 25.38040304, 29.37500662, 33.52687775, 19.05532721,
#        23.65846663, 16.74778447, 28.54056723, 10.23859037, 18.9192251 ,
#        27.77043041, 16.50302873, 28.87245196,  3.70941564, 17.62827922,
#        20.4340267 , 25.84935824, 19.47602326,  3.05944387, 20.1684582 ,
#        34.0248577 , 24.83884931, 30.60780877, 16.89521977, 24.49326211,
#        24.79826775, 18.99991922, 33.03647965, 13.37730949, 27.70135148,
#        30.30262973, 34.73631169, 21.26075689, 21.5128417 , 17.8395673 ,
#        19.33008444, 32.6386978 , 24.50362391, 25.08288312, 22.16356865,
#        20.47188334, 29.40731303, 20.84163969, 30.23464844, 22.9681642 ,
#        33.7214097 , 14.45952162, 40.505155  , 17.00795442, 14.01232118,
#        11.37393522,  7.26032148, 22.97553625, 22.23699946, 27.37976535,
#        17.44416475, 35.10239346, 24.54138001, 22.14508421, 35.10654908,
# ...

# %%
plt.scatter(y_test,y_pred)

# %%
error=y_test-y_pred
error
# Out:
# 455   -1.713448
# 142   -1.136765
# 311   -4.336338
# 232    4.377708
# 290   -4.487883
#          ...
# 282    6.077445
# 26     1.184450
# 177   -4.404681
# 140    1.274358
# 146   -0.129830
# Name: medv, Length: 152, dtype: float64

# %%
sns.displot(error,kind='kde')

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
print("mean_absolute_error=",mean_absolute_error(y_test,y_pred))
print("mean_squared_error=",mean_squared_error(y_test,y_pred))
# Out:
# mean_absolute_error= 3.576547659467719
# mean_squared_error= 27.206714061245773

# %%
from sklearn.metrics import r2_score
s=r2_score(y_test,y_pred)
s
# Out:
# 0.7154786619240121

# %%
a=df.iloc[:,:-1].values
a
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
a[0].reshape(1,-1)
# Out:
# array([[6.320e-03, 1.800e+01, 2.310e+00, 0.000e+00, 5.380e-01, 6.575e+00,
#         6.520e+01, 4.090e+00, 1.000e+00, 2.960e+02, 1.530e+01, 3.969e+02,
#         4.980e+00]])

# %%
sc.transform(a[0].reshape(1,-1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.37094562,  0.15898022, -1.23198786, -0.23570226, -0.09795533,
#          0.40777279, -0.06429407,  0.07904668, -0.97629129, -0.66410816,
#         -1.41013979,  0.43620858, -1.04799177]])

# %%
le.predict(sc.transform(a[0].reshape(1,-1)))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([29.73464179])

# %% [markdown]
# Prep Model for Deployement

# %%
import pickle
pickle.dump(le,open("le.pkl",'wb'))

# %%
pik_model=pickle.load(open("le.pkl",'rb'))

# %%
#Pediction on pickled File
pik_model.predict(sc.transform(a[0].reshape(1,-1)))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([29.73464179])
